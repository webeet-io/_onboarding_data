# %%
import pandas as pd
import re
import psycopg2
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")

# %%
##Psycopg2 connector

# %%
# SQLAlchemy connection string format:
# postgresql+psycopg2://user:password@host:port/dbname

DATABASE_URL = (
    "postgresql+psycopg2://neondb_owner:npg_CeS9fJg2azZD"
    "@ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech:5432/neondb"
    "?sslmode=require"
)

# Create engine and establish connection
engine = create_engine(DATABASE_URL)

# %%
import pandas as pd
df=pd.read_csv('/Users/sums/Documents/Webeet Internship/sat-results.csv')
df
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 488  27Q480                             JOHN ADAMS HIGH SCHOOL
# 489  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 490  05M304                              MOTT HALL HIGH SCHOOL
# 491  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 492  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
#
#     Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# 0                       29                             355
# 1                       91                             383
# 2                       70                             377
# 3                        7                             414
# 4                       44                             390
# ..                     ...                             ...
# 488                    403                             391
# 489                     85                             406
# 490                     54                             413
# 491                    264                             407
# 492                     65                             364
#
#     SAT Math Avg. Score SAT Writing Avg. Score SAT Critical Readng Avg. Score  \
# 0                   404                    363                            355
# 1                   423                    366                            383
# 2                   402                    370                            377
# 3                   401                    359                            414
# 4                   433                    384                            390
# ..                  ...                    ...                            ...
# 488                 409                    392                            391
# 489                 391                    392                            406
# 490                 399                    398                            413
# 491                 440                    393                            407
# 492                 378                    348                            364
#
#      internal_school_id contact_extension pct_students_tested  \
# 0                218160              x345                 78%
# 1                268547              x234                 NaN
# 2                236446              x123                 NaN
# 3                427826              x123                 92%
# 4                672714              x123                 92%
# ..                  ...               ...                 ...
# 488              863765               NaN                 92%
# 489              937579              x234                 NaN
# 490              296405              x123                 78%
# 491              892839               NaN                 92%
# 492              277389              x345                 92%
#
#      academic_tier_rating
# 0                     2.0
# 1                     3.0
# 2                     3.0
# 3                     4.0
# 4                     2.0
# ..                    ...
# 488                   1.0
# 489                   NaN
# 490                   2.0
# 491                   2.0
# 492                   NaN
#
# [493 rows x 11 columns]

# %%
new_df=df.drop_duplicates()
new_df
# Out:
#         DBN                                    SCHOOL NAME  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL
# 3    01M458                      FORSYTH SATELLITE ACADEMY
# 4    01M509                        MARTA VALLE HIGH SCHOOL
# ..      ...                                            ...
# 473  75X012               P.S. X012 LEWIS AND CLARK SCHOOL
# 474  75X754        J. M. RAPPORT SCHOOL CAREER DEVELOPMENT
# 475  79M645     SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION
# 476  79Q950                            GED PLUS s CITYWIDE
# 477  79X490                                PHOENIX ACADEMY
#
#     Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# 0                       29                             355
# 1                       91                             383
# 2                       70                             377
# 3                        7                             414
# 4                       44                             390
# ..                     ...                             ...
# 473                      s                               s
# 474                      s                               s
# 475                      s                               s
# 476                      8                             496
# 477                      9                             367
#
#     SAT Math Avg. Score SAT Writing Avg. Score SAT Critical Readng Avg. Score  \
# 0                   404                    363                            355
# 1                   423                    366                            383
# 2                   402                    370                            377
# 3                   401                    359                            414
# 4                   433                    384                            390
# ..                  ...                    ...                            ...
# 473                   s                      s                              s
# 474                   s                      s                              s
# 475                   s                      s                              s
# 476                 400                    426                            496
# 477                 370                    360                            367
#
#      internal_school_id contact_extension pct_students_tested  \
# 0                218160              x345                 78%
# 1                268547              x234                 NaN
# 2                236446              x123                 NaN
# 3                427826              x123                 92%
# 4                672714              x123                 92%
# ..                  ...               ...                 ...
# 473              733698              x234                 92%
# 474              976034              x345                 NaN
# 475              556924              x123                 85%
# 476              544514              x234                 92%
# 477              248647              x234                 85%
#
#      academic_tier_rating
# 0                     2.0
# 1                     3.0
# 2                     3.0
# 3                     4.0
# 4                     2.0
# ..                    ...
# 473                   1.0
# 474                   4.0
# 475                   1.0
# 476                   2.0
# 477                   NaN
#
# [478 rows x 11 columns]

# %%
# Clean and normalize column names
def clean_column(col):
    col = re.sub(r'[^A-Za-z0-9 _\.\-]', '', col)  # remove weird unicode chars
    col = col.strip().lower().replace(' ', '_')   # lowercase and snake_case
    return col

# %%
df.columns = [clean_column(col) for col in df.columns]

# Print cleaned columns
print(df.columns.tolist())
# Out:
# ['dbn', 'school_name', 'num_of_sat_test_takers', 'sat_critical_reading_avg._score', 'sat_math_avg._score', 'sat_writing_avg._score', 'sat_critical_readng_avg._score', 'internal_school_id', 'contact_extension', 'pct_students_tested', 'academic_tier_rating']

# %%
#Drop irrelevant or duplicate columns
df.drop(columns=['sat_critical_readng_avg._score', 'internal_school_id', 
    'contact_extension'], errors='ignore', inplace=True)

# %%
df.columns
# Out:
# Index(['dbn', 'school_name', 'num_of_sat_test_takers',
#        'sat_critical_reading_avg._score', 'sat_math_avg._score',
#        'sat_writing_avg._score', 'pct_students_tested',
#        'academic_tier_rating'],
#       dtype='object')

# %%
#Rename columns for clarity
df.rename(columns={'dbn': 'school_id',
    'school_name': 'school_name',
    'num_of_sat_test_takers': 'num_test_takers',
    'sat_critical_reading_avg._score': 'sat_reading',
    'sat_math_avg._score': 'sat_math',
    'sat_writing_avg._score': 'sat_writing'}, inplace=True)

# %%
#Convert SAT-related columns to numeric
score_cols = ['num_test_takers', 'sat_reading', 'sat_math', 'sat_writing']
for col in score_cols:
    df[col] = pd.to_numeric(df[col], errors='coerce')

# %%
score_cols
# Out:
# ['num_test_takers', 'sat_reading', 'sat_math', 'sat_writing']

# %%
# Remove rows with missing or invalid test data
df.dropna(subset=score_cols, inplace=True)

# %% [markdown]
# # We can also (Impute Using School Group Averages (e.g., by Borough or Tier))

# %%
print(df.columns)
# Out:
# Index(['school_id', 'school_name', 'num_test_takers', 'sat_reading',
#        'sat_math', 'sat_writing', 'pct_students_tested',
#        'academic_tier_rating'],
#       dtype='object')

# %%
#Detecting outliers

def clean_outliers(df, columns):
    """
    Removes outliers from given columns using the IQR method.
    Converts strings to numeric before processing.
    Works only on columns present in the DataFrame.
    """
    cleaned_df = df.copy()

    for col in columns:
        if col in cleaned_df.columns:
            # Convert to numeric if not already
            cleaned_df[col] = pd.to_numeric(cleaned_df[col], errors='coerce')

            # Calculate IQR
            Q1 = cleaned_df[col].quantile(0.25)
            Q3 = cleaned_df[col].quantile(0.75)
            IQR = Q3 - Q1

            # Filter out outliers
            cleaned_df = cleaned_df[
                (cleaned_df[col] >= Q1 - 1.5 * IQR) &
                (cleaned_df[col] <= Q3 + 1.5 * IQR)
            ]
        else:
            print(f"Skipping missing column: {col}")

    return cleaned_df


# Example usage:
numeric_cols = [
    'sat_reading', 'sat_math', 'sat_writing']

df_cleaned = clean_outliers(df, numeric_cols)

print(f"Original rows: {len(df)}, Cleaned rows: {len(df_cleaned)}")
# Out:
# Original rows: 435, Cleaned rows: 378

# %%
df_cleaned
# Out:
#     school_id                                        school_name  \
# 0      01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1      01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2      01M450                         EAST SIDE COMMUNITY SCHOOL
# 3      01M458                          FORSYTH SATELLITE ACADEMY
# 4      01M509                            MARTA VALLE HIGH SCHOOL
# ..        ...                                                ...
# 488    27Q480                             JOHN ADAMS HIGH SCHOOL
# 489    13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 490    05M304                              MOTT HALL HIGH SCHOOL
# 491    02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 492    07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
#
#      num_test_takers  sat_reading  sat_math  sat_writing pct_students_tested  \
# 0               29.0        355.0     404.0        363.0                 78%
# 1               91.0        383.0     423.0        366.0                 NaN
# 2               70.0        377.0     402.0        370.0                 NaN
# 3                7.0        414.0     401.0        359.0                 92%
# 4               44.0        390.0     433.0        384.0                 92%
# ..               ...          ...       ...          ...                 ...
# 488            403.0        391.0     409.0        392.0                 92%
# 489             85.0        406.0     391.0        392.0                 NaN
# 490             54.0        413.0     399.0        398.0                 78%
# 491            264.0        407.0     440.0        393.0                 92%
# 492             65.0        364.0     378.0        348.0                 92%
#
#      academic_tier_rating
# 0                     2.0
# 1                     3.0
# 2                     3.0
# 3                     4.0
# 4                     2.0
# ..                    ...
# 488                   1.0
# 489                   NaN
# 490                   2.0
# 491                   2.0
# 492                   NaN
#
# [378 rows x 8 columns]

# %%
df_cleaned.describe(include='all')
# Out:
#        school_id                                       school_name  \
# count        378                                               378
# unique       364                                               364
# top       02M520  MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# freq           3                                                 3
# mean         NaN                                               NaN
# std          NaN                                               NaN
# min          NaN                                               NaN
# 25%          NaN                                               NaN
# 50%          NaN                                               NaN
# 75%          NaN                                               NaN
# max          NaN                                               NaN
#
#         num_test_takers  sat_reading    sat_math  sat_writing  \
# count        378.000000   378.000000  378.000000   378.000000
# unique              NaN          NaN         NaN          NaN
# top                 NaN          NaN         NaN          NaN
# freq                NaN          NaN         NaN          NaN
# mean          92.050265   387.719577  396.904762   379.690476
# std          109.899907    31.311063   37.202385    30.602820
# min            6.000000   300.000000  312.000000   300.000000
# 25%           39.000000   367.000000  371.000000   359.000000
# 50%           59.000000   387.000000  391.000000   378.000000
# 75%           84.000000   406.000000  419.000000   397.750000
# max          762.000000   471.000000  499.000000   459.000000
#
#        pct_students_tested  academic_tier_rating
# count                  290            314.000000
# unique                   3                   NaN
# top                    78%                   NaN
# freq                    99                   NaN
# mean                   NaN              2.589172
# std                    NaN              1.121961
# min                    NaN              1.000000
# 25%                    NaN              2.000000
# 50%                    NaN              3.000000
# 75%                    NaN              4.000000
# max                    NaN              4.000000

# %%
#Normalize % tested
def convert_pct_as_int(val):
    if isinstance(val, str) and '%' in val:
        try:
            return int(val.replace('%', '').strip())
        except:
            return None
    return None

df_cleaned['pct_students_tested'] = df_cleaned['pct_students_tested'].apply(convert_pct_as_int)

# %%
df_cleaned['pct_students_tested']
# Out:
# 0      78.0
# 1       NaN
# 2       NaN
# 3      92.0
# 4      92.0
#        ...
# 488    92.0
# 489     NaN
# 490    78.0
# 491    92.0
# 492    92.0
# Name: pct_students_tested, Length: 378, dtype: float64

# %%
# Drop duplicates if any
df_cleaned.drop_duplicates(subset='school_id', inplace=True)

# %%
# Select final columns for upload
new_df = df_cleaned[[
    'school_id', 'school_name', 'num_test_takers',
    'sat_reading', 'sat_math', 'sat_writing',
    'pct_students_tested', 'academic_tier_rating'
]]

# %%
# Upload to database 
new_df.to_sql(
    name='sumi_sat_results_outliers_removal',       
    con=engine,     
    schema='nyc_schools',
    if_exists='replace',    
    index=False            
)

print("✅ Data uploaded successfully to nyc_schools.sumi_sat_results")
# Out:
# ✅ Data uploaded successfully to nyc_schools.sumi_sat_results

# %%
df_cleaned.head()
# Out:
#   school_id                                    school_name  num_test_takers  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES             29.0
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL             91.0
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL             70.0
# 3    01M458                      FORSYTH SATELLITE ACADEMY              7.0
# 4    01M509                        MARTA VALLE HIGH SCHOOL             44.0
#
#    sat_reading  sat_math  sat_writing  pct_students_tested  \
# 0        355.0     404.0        363.0                 78.0
# 1        383.0     423.0        366.0                  NaN
# 2        377.0     402.0        370.0                  NaN
# 3        414.0     401.0        359.0                 92.0
# 4        390.0     433.0        384.0                 92.0
#
#    academic_tier_rating
# 0                   2.0
# 1                   3.0
# 2                   3.0
# 3                   4.0
# 4                   2.0

# %%
df_cleaned.to_csv('cleaned_sat_data_outliers_removal.csv', index=False)
