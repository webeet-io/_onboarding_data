# %% [markdown]
# # 🧠 Day 4

# %% [markdown]
# ## 🔌 Step 1: Import Libraries

# %%
import pandas as pd
import numpy as np
import sqlalchemy
import psycopg2
from sqlalchemy import create_engine



pd.set_option('display.max_columns', None)

# %%
# !pip install sqlalchemy psycopg2-binary
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/lib/python3.11/dist-packages (2.0.42)
# Collecting psycopg2-binary
#   Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.9 kB)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy) (3.2.3)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy) (4.14.1)
# Downloading psycopg2_binary-2.9.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 37.4 MB/s eta 0:00:00
# Installing collected packages: psycopg2-binary
# Successfully installed psycopg2-binary-2.9.10

# %% [markdown]
# ## 🔐 Step 2: Connect to the Database

# %%
""" DB connection setup using hardcoded credentials (for onboarding only)
conn = psycopg2.connect(
    dbname="neondb",
    user="neondb_owner",
    password="npg_CeS9fJg2azZD",
    host="ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech",
    port="5432",
    sslmode="require"
)
cur = conn.cursor()"""

# %%
from sqlalchemy import create_engine

# Format: 'postgresql+psycopg2://user:password@host:port/dbname'
db_url = 'postgresql+psycopg2://neondb_owner:npg_CeS9fJg2azZD@ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech:5432/neondb'

engine = create_engine(db_url, connect_args={"sslmode": "require"})

# %%
df = pd.read_csv('sat-results.csv')
df.head()
# Out:
#       DBN                                    SCHOOL NAME  \
# 0  01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1  01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2  01M450                     EAST SIDE COMMUNITY SCHOOL
# 3  01M458                      FORSYTH SATELLITE ACADEMY
# 4  01M509                        MARTA VALLE HIGH SCHOOL
#
#   Num of SAT Test Takers SAT Critical Reading Avg. Score SAT Math Avg. Score  \
# 0                     29                             355                 404
# 1                     91                             383                 423
# 2                     70                             377                 402
# 3                      7                             414                 401
# 4                     44                             390                 433
#
#   SAT Writing Avg. Score SAT Critical Readng Avg. Score  internal_school_id  \
# 0                    363                            355              218160
# 1                    366                            383              268547
# 2                    370                            377              236446
# 3                    359                            414              427826
# 4                    384                            390              672714
#
#   contact_extension pct_students_tested  academic_tier_rating
# 0              x345                 78%                   2.0
# 1              x234                 NaN                   3.0
# 2              x123                 NaN                   3.0
# 3              x123                 92%                   4.0
# 4              x123                 92%                   2.0

# %%
print(df.columns.to_list())
# Out:
# ['DBN', 'SCHOOL NAME', 'Num of SAT Test Takers', 'SAT Critical Reading Avg. Score', 'SAT Math Avg. Score', 'SAT Writing Avg. Score', 'SAT Critical Readng Avg. Score', 'internal_school_id', 'contact_extension', 'pct_students_tested', 'academic_tier_rating']

# %%
# First, compare how often the values are equal
comparison = df["SAT Critical Reading Avg. Score"] == df["SAT Critical Readng Avg. Score"]
match_ratio = comparison.sum() / len(df)
print(f"Match ratio: {match_ratio:.2%}")
# Out:
# Match ratio: 100.00%

# %%
#Now we can safely drop the column with the typo and two other columns which are not meaningful:
df = df.drop(columns=['SAT Critical Readng Avg. Score', 'internal_school_id', 'contact_extension'])

#Clean column names:
df.columns = df.columns.str.strip().str.lower().str.replace(' ', '_')

# %%
dbn_counts = df['dbn'].value_counts()
duplicates = dbn_counts[dbn_counts > 1]
print(f"Number of duplicated DBNs: {len(duplicates)}")
# Out:
# Number of duplicated DBNs: 10

# %%
duplicate_rows = df[df['dbn'].isin(duplicates.index)]
display(duplicate_rows.sort_values('dbn'))
# Out:
#         dbn                                        school_name  \
# 35   02M419                               LANDMARK HIGH SCHOOL
# 486  02M419                               LANDMARK HIGH SCHOOL
# 52   02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 484  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 491  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 99   05M304                              MOTT HALL HIGH SCHOOL
# 490  05M304                              MOTT HALL HIGH SCHOOL
# 487  05M304                              MOTT HALL HIGH SCHOOL
# 481  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
# 492  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
# 119  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
# 483  09X525               BRONX LEADERSHIP ACADEMY HIGH SCHOOL
# 177  09X525               BRONX LEADERSHIP ACADEMY HIGH SCHOOL
# 479  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 258  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 489  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 478  14K685            EL PUENTE ACADEMY FOR PEACE AND JUSTICE
# 276  14K685            EL PUENTE ACADEMY FOR PEACE AND JUSTICE
# 306  17K543  SCIENCE, TECHNOLOGY AND RESEARCH EARLY COLLEGE...
# 485  17K543  SCIENCE, TECHNOLOGY AND RESEARCH EARLY COLLEGE...
# 331  19K420                       FRANKLIN K. LANE HIGH SCHOOL
# 482  19K420                       FRANKLIN K. LANE HIGH SCHOOL
# 488  27Q480                             JOHN ADAMS HIGH SCHOOL
# 414  27Q480                             JOHN ADAMS HIGH SCHOOL
# 480  27Q480                             JOHN ADAMS HIGH SCHOOL
#
#     num_of_sat_test_takers sat_critical_reading_avg._score  \
# 35                      62                             390
# 486                     62                             390
# 52                     264                             407
# 484                    264                             407
# 491                    264                             407
# 99                      54                             413
# 490                     54                             413
# 487                     54                             413
# 481                     65                             364
# 492                     65                             364
# 119                     65                             364
# 483                    114                             384
# 177                    114                             384
# 479                     85                             406
# 258                     85                             406
# 489                     85                             406
# 478                     28                             359
# 276                     28                             359
# 306                     69                             457
# 485                     69                             457
# 331                      s                               s
# 482                      s                               s
# 488                    403                             391
# 414                    403                             391
# 480                    403                             391
#
#     sat_math_avg._score sat_writing_avg._score pct_students_tested  \
# 35                  399                    381                 78%
# 486                 399                    381                 78%
# 52                  440                    393                 92%
# 484                 440                    393                 92%
# 491                 440                    393                 92%
# 99                  399                    398                 78%
# 490                 399                    398                 78%
# 487                 399                    398                 78%
# 481                 378                    348                 92%
# 492                 378                    348                 92%
# 119                 378                    348                 92%
# 483                 394                    388                 92%
# 177                 394                    388                 92%
# 479                 391                    392                 NaN
# 258                 391                    392                 NaN
# 489                 391                    392                 NaN
# 478                 335                    341                 92%
# 276                 335                    341                 92%
# 306                 462                    441                 85%
# 485                 462                    441                 85%
# 331                   s                      s                 78%
# 482                   s                      s                 78%
# 488                 409                    392                 92%
# 414                 409                    392                 92%
# 480                 409                    392                 92%
#
#      academic_tier_rating
# 35                    2.0
# 486                   2.0
# 52                    2.0
# 484                   2.0
# 491                   2.0
# 99                    2.0
# 490                   2.0
# 487                   2.0
# 481                   NaN
# 492                   NaN
# 119                   NaN
# 483                   1.0
# 177                   1.0
# 479                   NaN
# 258                   NaN
# 489                   NaN
# 478                   4.0
# 276                   4.0
# 306                   NaN
# 485                   NaN
# 331                   3.0
# 482                   3.0
# 488                   1.0
# 414                   1.0
# 480                   1.0

# %%
before = len(df)
df = df.drop_duplicates()
after = len(df)
print(f"Dropped rows: {before - after}")
# Out:
# Dropped rows: 15

# %% [markdown]
# It means some DBNs were duplicated more than once — i.e., some schools appeared three times instead of just twice.
#
# So, in total, 15 fully identical rows were removed.

# %%
print(df.columns.tolist())
# Out:
# ['dbn', 'school_name', 'num_of_sat_test_takers', 'sat_critical_reading_avg._score', 'sat_math_avg._score', 'sat_writing_avg._score', 'pct_students_tested', 'academic_tier_rating']

# %%
sat_columns = [
    'sat_critical_reading_avg._score',
    'sat_math_avg._score',
    'sat_writing_avg._score'
]
for col in sat_columns:
    print(f"\nUnique values in {col}:")
    print(df[col].value_counts())

for col in sat_columns:
    num_nans = df[col].isna().sum()
    print(f"{col}: {num_nans} missing (NaN) values")
# Out:
# Unique values in sat_critical_reading_avg._score:
# sat_critical_reading_avg._score
# s      57
# 367     8
# 384     8
# 370     8
# 398     8
#        ..
# 472     1
# 437     1
# 466     1
# 635     1
# 428     1
# Name: count, Length: 164, dtype: int64
#
# Unique values in sat_math_avg._score:
# sat_math_avg._score
# s       57
# 385      9
# 381      8
# 371      8
# 364      8
#         ..
# 1100     1
# 488      1
# 682      1
# 317      1
# 444      1
# Name: count, Length: 177, dtype: int64
#
# Unique values in sat_writing_avg._score:
# sat_writing_avg._score
# s      57
# 370     9
# 368     9
# 394     8
# 359     8
#        ..
# 466     1
# 417     1
# 470     1
# 397     1
# 422     1
# Name: count, Length: 163, dtype: int64
# sat_critical_reading_avg._score: 0 missing (NaN) values
# sat_math_avg._score: 0 missing (NaN) values
# sat_writing_avg._score: 0 missing (NaN) values

# %%
print(f"Initial shape: {df.shape}")
df = df[~df[sat_columns].isin(['s']).any(axis=1)]
for col in sat_columns:
    df[col] = pd.to_numeric(df[col])
for col in sat_columns:
    min_val = df[col].min()
    max_val = df[col].max()
    print(f"{col}: min={min_val}, max={max_val}")
# Out:
# Initial shape: (478, 8)
# sat_critical_reading_avg._score: min=279, max=679
# sat_math_avg._score: min=-10, max=1100
# sat_writing_avg._score: min=286, max=682

# %%
for col in sat_columns:
    df = df[(df[col] >= 200) & (df[col] <= 800)]
print(f"After dropping 's' rows and out of range scores: {df.shape}")
# Out:
# After dropping 's' rows and out of range scores: (416, 8)

# %%
print(df['pct_students_tested'].value_counts(dropna=False))
# Out:
# pct_students_tested
# 78%    111
# 85%    105
# NaN    103
# 92%     97
# Name: count, dtype: int64

# %%
def pct_to_float(x):
    if isinstance(x, str) and x.endswith('%'):
        return float(x.strip('%')) / 100
    else:
        return np.nan

df['pct_students_tested'] = df['pct_students_tested'].apply(pct_to_float)

# %%
print(df['pct_students_tested'].describe())
print(df['pct_students_tested'].isna().sum())
# Out:
# count    313.000000
# mean       0.846869
# std        0.057069
# min        0.780000
# 25%        0.780000
# 50%        0.850000
# 75%        0.920000
# max        0.920000
# Name: pct_students_tested, dtype: float64
# 103

# %%
print(df['academic_tier_rating'].value_counts(dropna=False))
# Out:
# academic_tier_rating
# 4.0    98
# 2.0    89
# 3.0    84
# 1.0    78
# NaN    67
# Name: count, dtype: int64

# %%
df['num_of_sat_test_takers'] = pd.to_numeric(
    df['num_of_sat_test_takers'],
    errors='coerce'
)

missing_test_takers = df['num_of_sat_test_takers'].isna().sum()
print(f"Missing values in num_of_sat_test_takers after conversion: {missing_test_takers}")
# Out:
# Missing values in num_of_sat_test_takers after conversion: 0

# %%
df['num_of_sat_test_takers'] = df['num_of_sat_test_takers'].astype(int)

# %%
print(df.dtypes)
# Out:
# dbn                                 object
# school_name                         object
# num_of_sat_test_takers               int64
# sat_critical_reading_avg._score      int64
# sat_math_avg._score                  int64
# sat_writing_avg._score               int64
# pct_students_tested                float64
# academic_tier_rating               float64
# dtype: object

# %%
# Save cleaned dataset
df.to_csv("cleaned_sat_results.csv", index=False)
print("✅ Cleaned dataset saved as cleaned_sat_results.csv")
# Out:
# ✅ Cleaned dataset saved as cleaned_sat_results.csv

# %%
tables_df = pd.read_sql("""
    SELECT table_schema, table_name
    FROM information_schema.tables
    WHERE table_schema NOT IN ('information_schema', 'pg_catalog')
    ORDER BY table_schema, table_name;
""", engine)

tables_df
# Out:
#           table_schema                            table_name
# 0   dependency_example                           departments
# 1   dependency_example                             districts
# 2   dependency_example                             employees
# 3   dependency_example                         neighborhoods
# 4          nyc_schools              Levon_cleaned_sat_scores
# 5          nyc_schools                 anastasia_sat_results
# 6          nyc_schools                     clara_sat_results
# 7          nyc_schools              cleaned_sat_results_anna
# 8          nyc_schools                deepshikha_sat_results
# 9          nyc_schools                   giovani_sat_results
# 10         nyc_schools                 high_school_directory
# 11         nyc_schools                     jyoti_sat_results
# 12         nyc_schools              najimohammed_sat_results
# 13         nyc_schools                            sat_scores
# 14         nyc_schools                     sat_scores_mariia
# 15         nyc_schools                   school_demographics
# 16         nyc_schools                  school_safety_report
# 17         nyc_schools                 sebastian_sat_results
# 18         nyc_schools                    sultan_sat_results
# 19         nyc_schools                      sumi_sat_results
# 20         nyc_schools       svitlana_experement_sat_results
# 21         nyc_schools  svitlana_experement_sat_scores_clean
# 22         nyc_schools                  svitlana_sat_results
# 23         nyc_schools       svitlana_sat_results_production
# 24              public              Levon_cleaned_sat_scores
# 25              public                           departments
# 26              public        dependency_example.departments
# 27              public                     geography_columns
# 28              public                      geometry_columns
# 29              public                           sat_results
# 30              public                            sat_scores
# 31              public                    sat_scores_giovani
# 32              public                       spatial_ref_sys
# 33    test_berlin_data                      crime_statistics
# 34    test_berlin_data                             districts
# 35    test_berlin_data                          green_spaces
# 36    test_berlin_data                             hospitals
# 37    test_berlin_data                           land_prices
# 38    test_berlin_data                     long_term_rentals
# 39    test_berlin_data         milieuschutz_protection_zones
# 40    test_berlin_data                          neighborhood
# 41    test_berlin_data                 neighborhood_pop_stat
# 42    test_berlin_data                         neighborhoods
# 43    test_berlin_data                           playgrounds
# 44    test_berlin_data                   regional_statistics
# 45    test_berlin_data           rent_stats_per_neighborhood
# 46    test_berlin_data                 rent_stats_per_street
# 47    test_berlin_data             rent_stats_per_street_kai
# 48    test_berlin_data                   short_time_listings
# 49    test_berlin_data                                 ubahn

# %%
df.to_sql(
    "cleaned_sat_results_anna",  # table name
    con=engine,
    schema="nyc_schools",
    if_exists="replace",         # replace if you rerun
    index=False,
    dtype={
        "dbn":                  sqlalchemy.types.Text(),
        "school_name":          sqlalchemy.types.Text(),
        "num_of_sat_test_takers": sqlalchemy.types.Integer(),
        "sat_critical_reading_avg._score": sqlalchemy.types.Integer(),
        "sat_math_avg._score": sqlalchemy.types.Integer(),
        "sat_writing_avg._score": sqlalchemy.types.Integer(),
        "pct_students_tested": sqlalchemy.types.Float(),
        "academic_tier_rating": sqlalchemy.types.Float()
    }
)
# Out:
# 416
