# %% [markdown]
# ## 🔌 Step 1: Import Libraries

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")

# %%
##Psycopg2 connector
import psycopg2

# %%
import numpy as np

# %% [markdown]
# ## Step 2: Connect to the Database

# %%
# SQLAlchemy connection string format:
# postgresql+psycopg2://user:password@host:port/dbname

DATABASE_URL = (
    "postgresql+psycopg2://neondb_owner:npg_CeS9fJg2azZD"
    "@ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech:5432/neondb"
    "?sslmode=require"
)

# Create engine and establish connection
engine = create_engine(DATABASE_URL)

# %% [markdown]
# ## Step 3: Load the dataset using pandas

# %%
import pandas as pd
df=pd.read_csv('/Users/claraneagu/Downloads/sat-results.csv')
df
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 488  27Q480                             JOHN ADAMS HIGH SCHOOL
# 489  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 490  05M304                              MOTT HALL HIGH SCHOOL
# 491  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 492  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
#
#     Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# 0                       29                             355
# 1                       91                             383
# ...

# %%
df.describe()
# Out:
#        internal_school_id  academic_tier_rating
# count          493.000000            402.000000
# mean        562172.943205              2.564677
# std         262138.627055              1.126443
# min         101855.000000              1.000000
# 25%         332013.000000              2.000000
# 50%         587220.000000              3.000000
# 75%         782993.000000              4.000000
# max         999398.000000              4.000000

# %% [markdown]
# ## Step 4: Instructions

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DBN                              493 non-null    object
#  1   SCHOOL NAME                      493 non-null    object
#  2   Num of SAT Test Takers           493 non-null    object
#  3   SAT Critical Reading Avg. Score  493 non-null    object
#  4   SAT Math Avg. Score              493 non-null    object
#  5   SAT Writing Avg. Score           493 non-null    object
#  6   SAT Critical Readng Avg. Score   493 non-null    object
#  7   internal_school_id               493 non-null    int64
#  8   contact_extension                388 non-null    object
#  9   pct_students_tested              376 non-null    object
#  10  academic_tier_rating             402 non-null    float64
# dtypes: float64(1), int64(1), object(9)
# memory usage: 42.5+ KB

# %%
# Fix inconsistent formatting
df['pct_students_tested'] = df['pct_students_tested'].str.replace('%', '').astype(float)
df
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 488  27Q480                             JOHN ADAMS HIGH SCHOOL
# 489  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 490  05M304                              MOTT HALL HIGH SCHOOL
# 491  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 492  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
#
#     Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# 0                       29                             355
# 1                       91                             383
# ...

# %%
# Changing the datatype from "object" to "numeric"
df["SAT Critical Reading Avg. Score"] = pd.to_numeric(df["SAT Critical Reading Avg. Score"], errors="coerce")
df["SAT Writing Avg. Score"] = pd.to_numeric(df["SAT Writing Avg. Score"], errors="coerce")
df["SAT Math Avg. Score"] = pd.to_numeric(df["SAT Math Avg. Score"], errors="coerce")
df["SAT Critical Reading Avg. Score"] = pd.to_numeric(df["SAT Critical Reading Avg. Score"], errors="coerce")
df["pct_students_tested"] = pd.to_numeric(df["pct_students_tested"], errors="coerce")

# %%
df.describe()
# Out:
#        SAT Critical Reading Avg. Score  SAT Math Avg. Score  \
# count                       435.000000           435.000000
# mean                        400.712644           417.643678
# std                          56.056774            86.991283
# min                         279.000000           -10.000000
# 25%                         368.000000           372.000000
# 50%                         391.000000           396.000000
# 75%                         416.000000           438.000000
# max                         679.000000          1100.000000
#
#        SAT Writing Avg. Score  internal_school_id  pct_students_tested  \
# count              435.000000          493.000000           376.000000
# mean               393.712644       562172.943205            84.683511
# std                 57.870447       262138.627055             5.718120
# min                286.000000       101855.000000            78.000000
# ...

# %%
df["Num of SAT Test Takers"] = pd.to_numeric(df["Num of SAT Test Takers"], errors="coerce")
df["SAT Critical Readng Avg. Score"] = pd.to_numeric(df["SAT Critical Readng Avg. Score"], errors="coerce")

# %%
# Replaces those invalid values with NaN (Not a Number)
# SAT Math scores should be between 200 and 800, so anything outside that range is likely bad data.
df.loc[
    (df["SAT Math Avg. Score"] < 200) | (df["SAT Math Avg. Score"] > 800),
    "SAT Math Avg. Score"
] = np.nan

# %%
df
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 488  27Q480                             JOHN ADAMS HIGH SCHOOL
# 489  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 490  05M304                              MOTT HALL HIGH SCHOOL
# 491  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 492  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
#
#      Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# 0                      29.0                            355.0
# 1                      91.0                            383.0
# ...

# %%
df.describe()
# Out:
#        Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# count              435.000000                       435.000000
# mean               111.402299                       400.712644
# std                154.806216                        56.056774
# min                  6.000000                       279.000000
# 25%                 42.000000                       368.000000
# 50%                 63.000000                       391.000000
# 75%                 97.500000                       416.000000
# max               1277.000000                       679.000000
#
#        SAT Math Avg. Score  SAT Writing Avg. Score  \
# count           430.000000              435.000000
# mean            413.341860              393.712644
# std              64.141429               57.870447
# min             312.000000              286.000000
# 25%             372.000000              360.000000
# 50%             395.000000              382.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 493 entries, 0 to 492
# Data columns (total 11 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   DBN                              493 non-null    object
#  1   SCHOOL NAME                      493 non-null    object
#  2   Num of SAT Test Takers           435 non-null    float64
#  3   SAT Critical Reading Avg. Score  435 non-null    float64
#  4   SAT Math Avg. Score              430 non-null    float64
#  5   SAT Writing Avg. Score           435 non-null    float64
#  6   SAT Critical Readng Avg. Score   435 non-null    float64
#  7   internal_school_id               493 non-null    int64
#  8   contact_extension                388 non-null    object
#  9   pct_students_tested              376 non-null    float64
#  10  academic_tier_rating             402 non-null    float64
# dtypes: float64(7), int64(1), object(3)
# ...

# %%
# Removes duplicate rows
new_df=df.drop_duplicates()
new_df
# Out:
#         DBN                                    SCHOOL NAME  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL
# 3    01M458                      FORSYTH SATELLITE ACADEMY
# 4    01M509                        MARTA VALLE HIGH SCHOOL
# ..      ...                                            ...
# 473  75X012               P.S. X012 LEWIS AND CLARK SCHOOL
# 474  75X754        J. M. RAPPORT SCHOOL CAREER DEVELOPMENT
# 475  79M645     SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION
# 476  79Q950                            GED PLUS s CITYWIDE
# 477  79X490                                PHOENIX ACADEMY
#
#      Num of SAT Test Takers  SAT Critical Reading Avg. Score  \
# 0                      29.0                            355.0
# 1                      91.0                            383.0
# 2                      70.0                            377.0
# ...

# %%
# Normalize column headers
new_df.columns = new_df.columns.str.lower().str.strip().str.replace(' ', '_').str.replace('.', '')
new_df
# Out:
#         dbn                                    school_name  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL
# 3    01M458                      FORSYTH SATELLITE ACADEMY
# 4    01M509                        MARTA VALLE HIGH SCHOOL
# ..      ...                                            ...
# 473  75X012               P.S. X012 LEWIS AND CLARK SCHOOL
# 474  75X754        J. M. RAPPORT SCHOOL CAREER DEVELOPMENT
# 475  79M645     SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION
# 476  79Q950                            GED PLUS s CITYWIDE
# 477  79X490                                PHOENIX ACADEMY
#
#      num_of_sat_test_takers  sat_critical_reading_avg_score  \
# 0                      29.0                           355.0
# 1                      91.0                           383.0
# 2                      70.0                           377.0
# ...

# %%
# Drop unrelated fields
#new_df = new_df.drop(columns=['sat_critical_readng_avg_score'])
#new_df

# %%
# Drop unrelated fields
new_df = new_df.drop(columns=['sat_critical_readng_avg_score', 'internal_school_id', 'contact_extension', 'academic_tier_rating'])
new_df
# Out:
#         dbn                                    school_name  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL
# 3    01M458                      FORSYTH SATELLITE ACADEMY
# 4    01M509                        MARTA VALLE HIGH SCHOOL
# ..      ...                                            ...
# 473  75X012               P.S. X012 LEWIS AND CLARK SCHOOL
# 474  75X754        J. M. RAPPORT SCHOOL CAREER DEVELOPMENT
# 475  79M645     SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION
# 476  79Q950                            GED PLUS s CITYWIDE
# 477  79X490                                PHOENIX ACADEMY
#
#      num_of_sat_test_takers  sat_critical_reading_avg_score  \
# 0                      29.0                           355.0
# 1                      91.0                           383.0
# 2                      70.0                           377.0
# ...

# %%
new_df.describe()
# Out:
#        num_of_sat_test_takers  sat_critical_reading_avg_score  \
# count              421.000000                      421.000000
# mean               110.320665                      400.850356
# std                155.534254                       56.802783
# min                  6.000000                      279.000000
# 25%                 41.000000                      368.000000
# 50%                 62.000000                      391.000000
# 75%                 95.000000                      416.000000
# max               1277.000000                      679.000000
#
#        sat_math_avg_score  sat_writing_avg_score  pct_students_tested
# count          416.000000             421.000000           363.000000
# mean           413.733173             393.985748            84.595041
# std             64.945638              58.635109             5.673305
# min            312.000000             286.000000            78.000000
# ...

# %%
# Save cleaned new_df to csv
new_df.to_csv("cleaned_sat_results.csv", index=False)

# %%
# Design the Schema

from sqlalchemy import text
create_table_sql = """

CREATE TABLE clara_sat_results (
    dbn VARCHAR(10) PRIMARY KEY,
    school_name TEXT,
    num_of_sat_test_takers INTEGER,
    sat_critical_reading_avg_score INTEGER,
    sat_math_avg_score INTEGER,
    sat_writing_avg_score INTEGER,
    pct_students_tested FLOAT
);
"""

# %%
# Send the datafreme to the db
new_df.to_sql(
    name='clara_sat_results',       
    con=engine,     
    schema='nyc_schools',
    if_exists='replace',    
    index=False            
)
# Out:
# 478

# %% [markdown]
# ## Step 5: Insights

# %% [markdown]
# **For creating the new table 'clara_sat_results' I have dropped the following columns:**
#
# | Column Name                      | Reason to Drop                                   |
# | -------------------------------- | ------------------------------------------------ |
# | `sat_critical_readng_avg_score`  | Duplicate with typo                              |
# | `internal_school_id`             | Not needed (dbn is enough)                       |
# | `contact_extension`              | Irrelevant to SAT scores                         |
# | `academic_tier_rating`           | Not directly related to SAT performance          |

# %% [markdown]
# **The new table 'clara_sat_resuts' contains the folowing columns:**
#
# | Column Name                       | Reason to Keep                                               |
# | --------------------------------- | ------------------------------------------------------------ |
# | `dbn`                             | Unique school ID — **primary key**                           |
# | `school_name`                     | Helpful for identification                                   |
# | `num_of_sat_test_takers`          | Important for context (more test takers = more reliable avg) |
# | `sat_critical_reading_avg_score`  | Valid SAT component                                          |
# | `sat_math_avg_score`              | Valid SAT component                                          |
# | `sat_writing_avg_score`           | Valid SAT component                                          |
# | `pct_students_tested`             | % of students at the school who took the SAT                 |
