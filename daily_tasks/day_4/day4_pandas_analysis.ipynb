# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
import warnings
warnings.filterwarnings("ignore")

# %%
##Psycopg2 connector

# %%
# SQLAlchemy connection string format:
# postgresql+psycopg2://user:password@host:port/dbname

DATABASE_URL = (
    "postgresql+psycopg2://neondb_owner:npg_CeS9fJg2azZD"
    "@ep-falling-glitter-a5m0j5gk-pooler.us-east-2.aws.neon.tech:5432/neondb"
    "?sslmode=require"
)

# Create engine and establish connection
engine = create_engine(DATABASE_URL)

# %%
import pandas as pd
df=pd.read_csv('sat-results.csv')
df
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 488  27Q480                             JOHN ADAMS HIGH SCHOOL
# 489  13K605  GEORGE WESTINGHOUSE CAREER AND TECHNICAL EDUCA...
# 490  05M304                              MOTT HALL HIGH SCHOOL
# 491  02M520   MURRY BERGTRAUM HIGH SCHOOL FOR BUSINESS CAREERS
# 492  07X221    SOUTH BRONX PREPARATORY: A COLLEGE BOARD SCHOOL
#
#     Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# 0                       29                             355
# 1                       91                             383
# ...

# %%
new_df=df.drop_duplicates()
new_df.columns=new_df.columns.str.lower().str.strip().str.replace('.', '').str.replace(' ', '_')
new_df
# Out:
#         dbn                                    school_name  \
# 0    01M292  HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448            UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                     EAST SIDE COMMUNITY SCHOOL
# 3    01M458                      FORSYTH SATELLITE ACADEMY
# 4    01M509                        MARTA VALLE HIGH SCHOOL
# ..      ...                                            ...
# 473  75X012               P.S. X012 LEWIS AND CLARK SCHOOL
# 474  75X754        J. M. RAPPORT SCHOOL CAREER DEVELOPMENT
# 475  79M645     SCHOOL FOR COOPERATIVE TECHNICAL EDUCATION
# 476  79Q950                            GED PLUS s CITYWIDE
# 477  79X490                                PHOENIX ACADEMY
#
#     num_of_sat_test_takers sat_critical_reading_avg_score sat_math_avg_score  \
# 0                       29                            355                404
# 1                       91                            383                423
# ...

# %%
# There are column contained invalid date( for ex. Num of SAT Test Takers was = s)  This rows are dropped.
clean_df=new_df[ new_df[ "num_of_sat_test_takers" ].str.contains( "s" )==False ]
clean_df
# Out:
#         dbn                                        school_name  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 466  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 467  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
# 471  75Q811                                          P.S. Q811
# 476  79Q950                                GED PLUS s CITYWIDE
# 477  79X490                                    PHOENIX ACADEMY
#
#     num_of_sat_test_takers sat_critical_reading_avg_score sat_math_avg_score  \
# 0                       29                            355                404
# ...

# %%
# There are column which is not needed. for Ex.Internal_school_id is redundant with dbn)
clean_cln1_df=clean_df.drop("internal_school_id",axis='columns')
clean_cln1_df
# Out:
#         dbn                                        school_name  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 466  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 467  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
# 471  75Q811                                          P.S. Q811
# 476  79Q950                                GED PLUS s CITYWIDE
# 477  79X490                                    PHOENIX ACADEMY
#
#     num_of_sat_test_takers sat_critical_reading_avg_score sat_math_avg_score  \
# 0                       29                            355                404
# ...

# %%
# There are column which is not needed.(For Ex.contact_extension will not help in data analysis)
clean_cln2_df=clean_cln1_df.drop("contact_extension",axis='columns')
clean_cln2_df
# Out:
#         DBN                                        SCHOOL NAME  \
# 0    01M292      HENRY STREET SCHOOL FOR INTERNATIONAL STUDIES
# 1    01M448                UNIVERSITY NEIGHBORHOOD HIGH SCHOOL
# 2    01M450                         EAST SIDE COMMUNITY SCHOOL
# 3    01M458                          FORSYTH SATELLITE ACADEMY
# 4    01M509                            MARTA VALLE HIGH SCHOOL
# ..      ...                                                ...
# 466  32K556  BUSHWICK LEADERS HIGH SCHOOL FOR ACADEMIC EXCE...
# 467  32K564                     BUSHWICK COMMUNITY HIGH SCHOOL
# 471  75Q811                                          P.S. Q811
# 476  79Q950                                GED PLUS s CITYWIDE
# 477  79X490                                    PHOENIX ACADEMY
#
#     Num of SAT Test Takers SAT Critical Reading Avg. Score  \
# 0                       29                             355
# 1                       91                             383
# ...

# %%
# Removing % values
clean_cln2_df['pct_students_tested'] = clean_cln2_df['pct_students_tested'].str.replace('%','')
# Removing Nan values

# %%
clean_cln2_df.to_csv('sat_results_cleaned.csv', index=False)

print("Cleaned data saved as sat_results_cleaned.csv.")
# Out:
# Cleaned data saved as sat_results_cleaned.csv.
