# %% [markdown]
# # 🐍 Introduction to Python and Pandas
#
# Welcome! In this notebook, you'll learn some fundamental concepts in **Python** and **pandas** by working with a real-world dataset.

# %% [markdown]
# ## Why Python?
#
# Python is:
# - Easy to learn and read
# - Powerful for data analysis and machine learning
# - Supported by a rich ecosystem of libraries (like `pandas`, `numpy`, `matplotlib`, `seaborn`)

# %% [markdown]
# ## General overview

# %%
name=....

# %%
x=3
x
# Out:
# 3

# %%
x=5

# %%
x*2
# Out:
# 10

# %%
# Variables
#int
age = 5
#float
height = 5.9
#str
name = "Alice"

# %%
age
# Out:
# 5

# %%
print(height)
# Out:
# 5.9

# %%
len(name)
# Out:
# 5

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#boolean
bol=True

# %%
type(bol)
# Out:
# bool

# %%
x=3
x>3
# Out:
# False

# %%
y>3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 y>3
#
# NameError: name 'y' is not defined

# %%
type(x>3)
# Out:
# bool

# %% [markdown]
# Read more here:<br>https://www.geeksforgeeks.org/python-data-types/

# %%
#Lists
fruits = ["apple", "banana", "cherry"]
fruits
# Out:
# ['apple', 'banana', 'cherry']

# %%
print("len of list:",len(fruits))
# Out:
# len of list: 3

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[2]
# Out:
# 'cherry'

# %%
for fruit in fruits:
    print(fruit)
# Out:
# apple
# banana
# cherry

# %%
for x in fruits:
    print(len(x))
# Out:
# 5
# 6
# 6

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Tuples are different from lists in that they are immutable, meaning their contents cannot be changed after creation, whereas lists are mutable and can be modified.

# %%
coordinates = (10, 20)

# %%
coordinates[0]
# Out:
# 10

# %% [markdown]
# A Series is like a list, but with labels and data-aware features, making it much more powerful for data analysis.

# %%
grades_list = [85, 90, 78]
print(grades_list[1])  #
# Out:
# 90

# %%
# !pip install pandas

# %%
import pandas as pd

grades_series = pd.Series(grades_list, index=["Alice", "Bob", "Bob"])
grades_series
# Out:
# Alice    85
# Bob      90
# Bob      78
# dtype: int64

# %%
print(grades_series["Bob"])
# Out:
# Bob    90
# Bob    78
# dtype: int64

# %%
diction={'Alice':85,'Bob':90, 'Bob':78}
diction
# Out:
# {'Alice': 85, 'Bob': 78}

# %%
# Functions
def multi(x,y):
    muliplication=x*y
    return muliplication
multi(x=5,y=2)
# Out:
# 10

# %%
multi(5,3)
# Out:
# 15

# %%
result=multi(5,4)
result
# Out:
# 20

# %%
result<10
# Out:
# False

# %%
age=17
age>=18
# Out:
# False

# %%
age=20
age>=18
# Out:
# True

# %%
age=17
# Condition
if age>=18:
    print("allowed")
else:
    print("not allowed")
# Out:
# not allowed

# %%
def choice(x):
    if x>=18:
        print("allowed")
    else:
        print("not allowed")

# %%
choice(20)
# Out:
# allowed

# %%
choice(12)
# Out:
# not allowed

# %% [markdown]
# # Dataframes

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Load the dataset
df = pd.read_csv("school-safety-report.csv")
df
# Out:
#      School Year Building Code     DBN  \
# 0        2015-16          K006  17K006
# 1        2015-16          K005  16K005
# 2        2015-16          K003  13K003
# 3        2015-16          K002     NaN
# 4        2015-16          K002  75K141
# ...          ...           ...     ...
# 6305     2013-14          K055  23K493
# 6306     2013-14          K054  13K054
# 6307     2013-14          K052  22K052
# 6308     2013-14          K051  15K051
# 6309     2013-14          K050     NaN
#
#                                     Location Name Location Code  \
# 0                                        P.S. 006          K006
# 1                      P.S. 005 Dr. Ronald Mcnair          K005
# 2                    P.S. 003 The Bedford Village          K003
# 3       655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
# 4                                       P.S. K141          K141
# ...                                           ...           ...
# ...

# %%
## main info
df.head()
# Out:
#   School Year Building Code     DBN  \
# 0     2015-16          K006  17K006
# 1     2015-16          K005  16K005
# 2     2015-16          K003  13K003
# 3     2015-16          K002     NaN
# 4     2015-16          K002  75K141
#
#                                Location Name Location Code  \
# 0                                   P.S. 006          K006
# 1                 P.S. 005 Dr. Ronald Mcnair          K005
# 2               P.S. 003 The Bedford Village          K003
# 3  655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
# 4                                  P.S. K141          K141
#
#                Address Borough  Geographical District Code Register  \
# 0     43 SNYDER AVENUE       K                        17.0      712
# 1   820 HANCOCK STREET       K                        16.0      231
# 2  50 JEFFERSON AVENUE       K                        13.0      450
# 3  655 PARKSIDE AVENUE       K                        17.0     1378
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6310 entries, 0 to 6309
# Data columns (total 34 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   School Year                 6310 non-null   object
#  1   Building Code               6310 non-null   object
#  2   DBN                         5308 non-null   object
#  3   Location Name               6310 non-null   object
#  4   Location Code               5308 non-null   object
#  5   Address                     6308 non-null   object
#  6   Borough                     6308 non-null   object
#  7   Geographical District Code  6304 non-null   float64
#  8   Register                    6050 non-null   object
#  9   Building Name               3756 non-null   object
#  10  # Schools                   6310 non-null   int64
#  11  Schools in Building         6310 non-null   object
#  12  Major N                     3561 non-null   float64
# ...

# %%
df.columns
# Out:
# Index(['School Year', 'Building Code', 'DBN', 'Location Name', 'Location Code',
#        'Address', 'Borough', 'Geographical District Code', 'Register',
#        'Building Name', '# Schools', 'Schools in Building', 'Major N', 'Oth N',
#        'NoCrim N', 'Prop N', 'Vio N', 'ENGroupA', 'RangeA', 'AvgOfMajor N',
#        'AvgOfOth N', 'AvgOfNoCrim N', 'AvgOfProp N', 'AvgOfVio N',
#        'Borough Name', 'Postcode', 'Latitude', 'Longitude', 'Community Board',
#        'Council District ', 'Census Tract', 'BIN', 'BBL', 'NTA'],
#       dtype='object')

# %%
## methods to clean column names
example=df.columns[-5]
example
# Out:
# 'Council District '

# %%
example
# Out:
# 'Council District '

# %%
council_district

# %%
example.lower()
# Out:
# 'council district '

# %%
example.strip()
# Out:
# 'Council District'

# %%
example.replace(' ','_')
# Out:
# 'Council_District_'

# %%
example.lower().strip().replace(' ','_')
# Out:
# 'council_district'

# %%
example
# Out:
# 'Council District '

# %%
example=example.lower().strip().replace(' ','_')
example
# Out:
# 'council_district'

# %%
new_list=[]
new_list
# Out:
# []

# %%
new_element='5'
new_list.append(new_element)

# %%
new_list
# Out:
# ['5']

# %%
new_col_names=[]
new_col_names
# Out:
# []

# %%
df.columns
# Out:
# Index(['School Year', 'Building Code', 'DBN', 'Location Name', 'Location Code',
#        'Address', 'Borough', 'Geographical District Code', 'Register',
#        'Building Name', '# Schools', 'Schools in Building', 'Major N', 'Oth N',
#        'NoCrim N', 'Prop N', 'Vio N', 'ENGroupA', 'RangeA', 'AvgOfMajor N',
#        'AvgOfOth N', 'AvgOfNoCrim N', 'AvgOfProp N', 'AvgOfVio N',
#        'Borough Name', 'Postcode', 'Latitude', 'Longitude', 'Community Board',
#        'Council District ', 'Census Tract', 'BIN', 'BBL', 'NTA'],
#       dtype='object')

# %%
for col in df.columns:
    stripped_name=col.lower().strip().replace(' ','_')
    new_col_names.append(stripped_name)
    print(stripped_name,'-appended to list')
# Out:
# school_year -appended to list
# building_code -appended to list
# dbn -appended to list
# location_name -appended to list
# location_code -appended to list
# address -appended to list
# borough -appended to list
# geographical_district_code -appended to list
# register -appended to list
# building_name -appended to list
# #_schools -appended to list
# schools_in_building -appended to list
# major_n -appended to list
# oth_n -appended to list
# nocrim_n -appended to list
# prop_n -appended to list
# vio_n -appended to list
# engroupa -appended to list
# rangea -appended to list
# avgofmajor_n -appended to list
# avgofoth_n -appended to list
# avgofnocrim_n -appended to list
# avgofprop_n -appended to list
# avgofvio_n -appended to list
# borough_name -appended to list
# postcode -appended to list
# latitude -appended to list
# longitude -appended to list
# community_board -appended to list
# council_district -appended to list
# census_tract -appended to list
# bin -appended to list
# ...

# %%
new_col_names
# Out:
# ['school_year',
#  'building_code',
#  'dbn',
#  'location_name',
#  'location_code',
#  'address',
#  'borough',
#  'geographical_district_code',
#  'register',
#  'building_name',
#  '#_schools',
#  'schools_in_building',
#  'major_n',
#  'oth_n',
#  'nocrim_n',
#  'prop_n',
#  'vio_n',
#  'engroupa',
#  'rangea',
#  'avgofmajor_n',
#  'avgofoth_n',
#  'avgofnocrim_n',
#  'avgofprop_n',
#  'avgofvio_n',
#  'borough_name',
#  'postcode',
#  'latitude',
#  'longitude',
#  'community_board',
#  'council_district',
#  'census_tract',
#  'bin',
#  'bbl',
#  'nta']

# %%
## replacing. column names
new_col_names=[]
for col in df.columns:
        stripped_name=col.lower().strip().replace(' ','_')
        new_col_names.append(stripped_name)
df.columns=new_col_names
df.head()
# Out:
#   school_year building_code     dbn  \
# 0     2015-16          K006  17K006
# 1     2015-16          K005  16K005
# 2     2015-16          K003  13K003
# 3     2015-16          K002     NaN
# 4     2015-16          K002  75K141
#
#                                location_name location_code  \
# 0                                   P.S. 006          K006
# 1                 P.S. 005 Dr. Ronald Mcnair          K005
# 2               P.S. 003 The Bedford Village          K003
# 3  655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
# 4                                  P.S. K141          K141
#
#                address borough  geographical_district_code register  \
# 0     43 SNYDER AVENUE       K                        17.0      712
# 1   820 HANCOCK STREET       K                        16.0      231
# 2  50 JEFFERSON AVENUE       K                        13.0      450
# 3  655 PARKSIDE AVENUE       K                        17.0     1378
# ...

# %%
##working with columns

# %%
df['community_board']
# Out:
# 0       14.0
# 1        3.0
# 2        3.0
# 3        9.0
# 4        9.0
#         ...
# 6305    16.0
# 6306     3.0
# 6307    15.0
# 6308     6.0
# 6309     1.0
# Name: community_board, Length: 6310, dtype: float64

# %%
#for rows
##1 row
df.iloc[0]
# Out:
# school_year                                                             2015-16
# building_code                                                              K006
# dbn                                                                      17K006
# location_name                                                          P.S. 006
# location_code                                                              K006
# address                                                        43 SNYDER AVENUE
# borough                                                                       K
# geographical_district_code                                                 17.0
# register                                                                    712
# building_name                                                               NaN
# #_schools                                                                     1
# schools_in_building                                                    P.S. 006
# ...

# %%
##slicing
df[0:10]
# Out:
#   school_year building_code     dbn  \
# 0     2015-16          K006  17K006
# 1     2015-16          K005  16K005
# 2     2015-16          K003  13K003
# 3     2015-16          K002     NaN
# 4     2015-16          K002  75K141
# 5     2015-16          K002  84K704
# 6     2015-16          K002  17K002
# 7     2015-16          X953  75XHOS
# 8     2015-16          K001  15K001
# 9     2015-16          K008  13K008
#
#                                location_name location_code  \
# 0                                   P.S. 006          K006
# 1                 P.S. 005 Dr. Ronald Mcnair          K005
# 2               P.S. 003 The Bedford Village          K003
# 3  655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
# 4                                  P.S. K141          K141
# 5                 EXPLORE CHARTER SCHOOL(BS)          K704
# 6               Parkside Preparatory Academy          K002
# 7                   Hospital Schools - Bronx          X402
# ...

# %%
df['community_board']
# Out:
# 0       14.0
# 1        3.0
# 2        3.0
# 3        9.0
# 4        9.0
#         ...
# 6305    16.0
# 6306     3.0
# 6307    15.0
# 6308     6.0
# 6309     1.0
# Name: community_board, Length: 6310, dtype: float64

# %%
x=15
x>10
# Out:
# True

# %%
df['community_board']>10
# Out:
# 0        True
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 6305     True
# 6306    False
# 6307     True
# 6308    False
# 6309    False
# Name: community_board, Length: 6310, dtype: bool

# %%
## filtering df
df[df['community_board']>10]
# Out:
#      school_year building_code           dbn  \
# 0        2015-16          K006        17K006
# 10       2015-16          K095        21K095
# 11       2015-16          K165        23K165
# 25       2015-16          X839        11X418
# 47       2015-16          X722        75X721
# ...          ...           ...           ...
# 6288     2013-14          K096        21K096
# 6303     2013-14          K055           NaN
# 6304     2013-14          K055  84K626
# 6305     2013-14          K055        23K493
# 6307     2013-14          K052        22K052
#
#                                      location_name location_code  \
# 0                                         P.S. 006          K006
# 10                          P.S. 095 The Gravesend          K095
# 11                             P.S. 165 Ida Posner          K165
# 25           Bronx High School for the Visual Arts          X418
# 47            P.S. X721 - Stephen McSweeney School          X721
# ...

# %%
## only MANHATTAN 
df[df['borough_name']=='MANHATTAN']
# Out:
#      school_year building_code     dbn  \
# 990      2015-16          MANN  84M353
# 991      2015-16          M971  02M397
# 992      2015-16          M970  05M670
# 994      2015-16          M933  02M933
# 995      2015-16          M920  02M570
# ...          ...           ...     ...
# 5687     2013-14          M002  02M002
# 5688     2013-14          M001  02M001
# 5701     2013-14          M089  02M089
# 5835     2013-14          M008  06M008
# 5889     2013-14          M066  02M151
#
#                                           location_name location_code  \
# 990              NEW HEIGHTS ACADEMY CHARTER SCHOOL(MN)          M353
# 991                                SPRUCE STREET SCHOOL          M397
# 992   Thurgood Marshall Academy for Learning and Social          M670
# 994                            City Knoll Middle School          M339
# 995                       Satellite Academy High School          M570
# ...

# %%
manhattan=df[df['borough_name']=='MANHATTAN']
manhattan
# Out:
#      school_year building_code     dbn  \
# 990      2015-16          MANN  84M353
# 991      2015-16          M971  02M397
# 992      2015-16          M970  05M670
# 994      2015-16          M933  02M933
# 995      2015-16          M920  02M570
# ...          ...           ...     ...
# 5687     2013-14          M002  02M002
# 5688     2013-14          M001  02M001
# 5701     2013-14          M089  02M089
# 5835     2013-14          M008  06M008
# 5889     2013-14          M066  02M151
#
#                                           location_name location_code  \
# 990              NEW HEIGHTS ACADEMY CHARTER SCHOOL(MN)          M353
# 991                                SPRUCE STREET SCHOOL          M397
# 992   Thurgood Marshall Academy for Learning and Social          M670
# 994                            City Knoll Middle School          M339
# 995                       Satellite Academy High School          M570
# ...

# %%
df
# Out:
#      school_year building_code     dbn  \
# 0        2015-16          K006  17K006
# 1        2015-16          K005  16K005
# 2        2015-16          K003  13K003
# 3        2015-16          K002     NaN
# 4        2015-16          K002  75K141
# ...          ...           ...     ...
# 6305     2013-14          K055  23K493
# 6306     2013-14          K054  13K054
# 6307     2013-14          K052  22K052
# 6308     2013-14          K051  15K051
# 6309     2013-14          K050     NaN
#
#                                     location_name location_code  \
# 0                                        P.S. 006          K006
# 1                      P.S. 005 Dr. Ronald Mcnair          K005
# 2                    P.S. 003 The Bedford Village          K003
# 3       655 PARKSIDE AVENUE CONSOLIDATED LOCATION           NaN
# 4                                       P.S. K141          K141
# ...                                           ...           ...
# ...

# %%
manhattan.head()
# Out:
#     school_year building_code     dbn  \
# 990     2015-16          MANN  84M353
# 991     2015-16          M971  02M397
# 992     2015-16          M970  05M670
# 994     2015-16          M933  02M933
# 995     2015-16          M920  02M570
#
#                                          location_name location_code  \
# 990             NEW HEIGHTS ACADEMY CHARTER SCHOOL(MN)          M353
# 991                               SPRUCE STREET SCHOOL          M397
# 992  Thurgood Marshall Academy for Learning and Social          M670
# 994                           City Knoll Middle School          M339
# 995                      Satellite Academy High School          M570
#
#                        address borough  geographical_district_code register  \
# 990         1818 Amsterdam Ave       M                         6.0      759
# 991           12 SPRUCE STREET       M                         2.0      443
# 992  200-214 WEST 135TH STREET       M                         5.0      549
# ...

# %%
manhattan.loc[0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:2263, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:2273, in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
## column stat 

df['borough_name'].unique()
# Out:
# array(['BROOKLYN ', 'BRONX    ', 'QUEENS   ', nan, 'STATEN IS',
#        'MANHATTAN'], dtype=object)

# %%
df['borough_name'].nunique()
# Out:
# 5

# %%
df['borough_name'].value_counts()
# Out:
# BROOKLYN     2044
# BRONX        1551
# MANHATTAN    1247
# QUEENS       1189
# STATEN IS     255
# Name: borough_name, dtype: int64

# %%
df['#_schools'].describe()
# Out:
# count    6310.000000
# mean        2.277179
# std         1.604115
# min         1.000000
# 25%         1.000000
# 50%         2.000000
# 75%         3.000000
# max        11.000000
# Name: #_schools, dtype: float64

# %%
df['#_schools'].max()
# Out:
# 11

# %%
dataframe.groupby([column_to_group_by])[what_i_am_aggregating].function()

# %%
dataframe.groupby(['school_name'])['age'].mean()

# %%
## groupby 

df.groupby(['borough_name'])['dbn'].nunique()
# Out:
# borough_name
# BRONX        457
# BROOKLYN     649
# MANHATTAN    367
# QUEENS       372
# STATEN IS     80
# Name: dbn, dtype: int64

# %%
df.groupby('borough_name')['#_schools'].describe()
# Out:
#                count      mean       std  min  25%  50%  75%   max
# borough_name
# BRONX         1551.0  2.892972  2.092727  1.0  1.0  2.0  3.0  11.0
# BROOKLYN      2044.0  2.120841  1.222475  1.0  1.0  2.0  3.0   6.0
# MANHATTAN     1247.0  2.567763  1.610067  1.0  1.0  2.0  3.0   9.0
# QUEENS        1189.0  1.667788  1.170548  1.0  1.0  1.0  2.0   7.0
# STATEN IS      255.0  1.305882  0.554655  1.0  1.0  1.0  2.0   3.0

# %%
df.columns
# Out:
# Index(['school_year', 'building_code', 'dbn', 'location_name', 'location_code',
#        'address', 'borough', 'geographical_district_code', 'register',
#        'building_name', '#_schools', 'schools_in_building', 'major_n', 'oth_n',
#        'nocrim_n', 'prop_n', 'vio_n', 'engroupa', 'rangea', 'avgofmajor_n',
#        'avgofoth_n', 'avgofnocrim_n', 'avgofprop_n', 'avgofvio_n',
#        'borough_name', 'postcode', 'latitude', 'longitude', 'community_board',
#        'council_district', 'census_tract', 'bin', 'bbl', 'nta'],
#       dtype='object')

# %%
pd.pivot_table(df,index='school_year',columns=['borough_name'],values='nocrim_n',aggfunc='sum')
# Out:
# borough_name  BRONX      BROOKLYN   MANHATTAN  QUEENS     STATEN IS
# school_year
# 2013-14          1124.0     1064.0      629.0      598.0      323.0
# 2014-15          1241.0     1118.0      736.0      563.0      282.0
# 2015-16          1241.0     1211.0      696.0      583.0      319.0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Read more here: <br>
#     https://python.plainenglish.io/a-comprehensive-guide-to-pandas-cheat-sheet-for-data-science-enthusiasts-b6f131ab5284

# %% [markdown]
# ### 📈 Visualization

# %%
df.groupby(['borough_name'])['dbn'].nunique()
# Out:
# borough_name
# BRONX        457
# BROOKLYN     649
# MANHATTAN    367
# QUEENS       372
# STATEN IS     80
# Name: dbn, dtype: int64

# %%
unique_schools=df.groupby(['borough_name'])['dbn'].nunique().reset_index()
unique_schools
# Out:
#   borough_name  dbn
# 0    BRONX      457
# 1    BROOKLYN   649
# 2    MANHATTAN  367
# 3    QUEENS     372
# 4    STATEN IS   80

# %%
import seaborn as sns
sns.barplot(x="borough_name", y="dbn", data=unique_schools)
# Out:
# <Axes: xlabel='borough_name', ylabel='dbn'>

# %% [markdown]
# # 🧠 Insights
#
# 1. Brooklyn has the highest number of schools.
# 2. Many Brooklyn schools offer Grade 9 entry.
# 3. Differences in student population and grade offerings vary by borough.
