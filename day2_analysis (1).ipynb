# %%
import pandas as pd

df = pd.read_csv('/content/high_school_directory - Sheet1.csv')

# %%
df.head()
# Out:
#       dbn                                        school_name    borough  \
# 0  27Q260          Frederick Douglass Academy VI High School     Queens
# 1  21K559        Life Academy High School for Film and Music   Brooklyn
# 2  16K393     Frederick Douglass Academy IV Secondary School   Brooklyn
# 3  08X305                               Pablo Neruda Academy      Bronx
# 4  03M485  Fiorello H. LaGuardia High School of Music & A...  Manhattan
#
#   building_code  phone_number    fax_number  grade_span_min  grade_span_max  \
# 0          Q465  718-471-2154  718-471-2890             9.0              12
# 1          K400  718-333-7750  718-333-7775             9.0              12
# 2          K026  718-574-2820  718-574-2821             9.0              12
# 3          X450  718-824-1682  718-824-1663             9.0              12
# 4          M485  212-496-0700  212-724-5748             9.0              12
#
# ...

# %%
df.columns
# Out:
# Index(['dbn', 'school_name', 'borough', 'building_code', 'phone_number',
#        'fax_number', 'grade_span_min', 'grade_span_max', 'expgrade_span_min',
#        'expgrade_span_max', 'bus', 'subway', 'primary_address_line_1', 'city',
#        'state_code', 'postcode', 'website', 'total_students', 'campus_name',
#        'school_type', 'overview_paragraph', 'program_highlights',
#        'language_classes', 'advancedplacement_courses', 'online_ap_courses',
#        'online_language_courses', 'extracurricular_activities',
#        'psal_sports_boys', 'psal_sports_girls', 'psal_sports_coed',
#        'school_sports', 'partner_cbo', 'partner_hospital', 'partner_highered',
#        'partner_cultural', 'partner_nonprofit', 'partner_corporate',
#        'partner_financial', 'partner_other', 'addtl_info1', 'addtl_info2',
#        'start_time', 'end_time', 'se_services', 'ell_programs',
#        'school_accessibility_description', 'number_programs', 'priority01',
# ...

# %%
new_column_names = []
new_column_names
# Out:
# []

# %%
for columns in df.columns:
  cleaned_names = columns.lower().strip().replace(' ', '_')
  new_column_names.append(cleaned_names)
  print(cleaned_names)
# Out:
# dbn
# school_name
# borough
# building_code
# phone_number
# fax_number
# grade_span_min
# grade_span_max
# expgrade_span_min
# expgrade_span_max
# bus
# subway
# primary_address_line_1
# city
# state_code
# postcode
# website
# total_students
# campus_name
# school_type
# overview_paragraph
# program_highlights
# language_classes
# advancedplacement_courses
# online_ap_courses
# online_language_courses
# extracurricular_activities
# psal_sports_boys
# psal_sports_girls
# psal_sports_coed
# school_sports
# partner_cbo
# partner_hospital
# partner_highered
# partner_cultural
# partner_nonprofit
# partner_corporate
# partner_financial
# partner_other
# addtl_info1
# addtl_info2
# start_time
# end_time
# se_services
# ell_programs
# school_accessibility_description
# number_programs
# priority01
# priority02
# priority03
# priority04
# priority05
# priority06
# priority07
# priority08
# priority09
# priority10
# location_1
# community_board
# council_district
# census_tract
# bin
# bbl
# ...

# %%
new_column_names
# Out:
# ['dbn',
#  'school_name',
#  'borough',
#  'building_code',
#  'phone_number',
#  'fax_number',
#  'grade_span_min',
#  'grade_span_max',
#  'expgrade_span_min',
#  'expgrade_span_max',
#  'bus',
#  'subway',
#  'primary_address_line_1',
#  'city',
#  'state_code',
#  'postcode',
#  'website',
#  'total_students',
#  'campus_name',
#  'school_type',
#  'overview_paragraph',
#  'program_highlights',
#  'language_classes',
#  'advancedplacement_courses',
#  'online_ap_courses',
#  'online_language_courses',
#  'extracurricular_activities',
#  'psal_sports_boys',
#  'psal_sports_girls',
#  'psal_sports_coed',
#  'school_sports',
#  'partner_cbo',
#  'partner_hospital',
#  'partner_highered',
#  'partner_cultural',
#  'partner_nonprofit',
#  'partner_corporate',
#  'partner_financial',
#  'partner_other',
#  'addtl_info1',
#  'addtl_info2',
#  'start_time',
#  'end_time',
#  'se_services',
#  'ell_programs',
#  'school_accessibility_description',
#  'number_programs',
#  'priority01',
# ...

# %%
df['borough']
# Out:
# 0         Queens
# 1       Brooklyn
# 2       Brooklyn
# 3          Bronx
# 4      Manhattan
#          ...
# 430    Manhattan
# 431        Bronx
# 432     Brooklyn
# 433    Manhattan
# 434     Brooklyn
# Name: borough, Length: 435, dtype: object

# %%
df[df['borough']=='Brooklyn']
# Out:
#         dbn                                        school_name   borough  \
# 1    21K559        Life Academy High School for Film and Music  Brooklyn
# 2    16K393     Frederick Douglass Academy IV Secondary School  Brooklyn
# 7    17K122  Pathways in Technology Early College High Scho...  Brooklyn
# 10   23K644                     Eagle Academy for Young Men II  Brooklyn
# 12   15K462                           Secondary School for Law  Brooklyn
# ..      ...                                                ...       ...
# 422  17K524      International High School at Prospect Heights  Brooklyn
# 423  17K408                 Academy of Hospitality and Tourism  Brooklyn
# 427  15K592                Khalil Gibran International Academy  Brooklyn
# 432  32K549                 Bushwick School for Social Justice  Brooklyn
# 434  21K344      Rachel Carson High School for Coastal Studies  Brooklyn
#
#     building_code  phone_number    fax_number  grade_span_min  grade_span_max  \
# ...

# %%
total_brooklyn_schools = df[df['borough'] == 'Brooklyn']['dbn'].nunique()
total_brooklyn_schools
# Out:
# 121

# %%
df[(df['expgrade_span_min'] <=9) & (df['expgrade_span_max']>=9)]
# Out:
#         dbn                                        school_name    borough  \
# 7    17K122  Pathways in Technology Early College High Scho...   Brooklyn
# 8    08X348              Schuylerville Preparatory High School      Bronx
# 9    24Q236      International High School for Health Sciences     Queens
# 34   06M211  Inwood Early College for Health and Informatio...  Manhattan
# 47   29Q327                    Eagle Academy for Young Men III     Queens
# 82   16K765           Nelson Mandela School for Social Justice   Brooklyn
# 84   30Q258                            Energy Tech High School     Queens
# 92   27Q314                           Epic High School – South     Queens
# 125  02M135  The Urban Assembly School for Emergency Manage...  Manhattan
# 142  26Q315      Business Technology Early College High School     Queens
# 144  25Q241            Queens High School for Language Studies     Queens
# 148  25Q240                                    Veritas Academy     Queens
# ...

# %%
grade9_schools = df[(df['expgrade_span_min'] <=9) & (df['expgrade_span_max']>=9)]['dbn'].nunique()
grade9_schools
# Out:
# 31

# %%
count_schools_borough = df.groupby(['borough'])['school_name'].nunique().reset_index()
count_schools_borough
# Out:
#          borough  school_name
# 0          Bronx          118
# 1       Brooklyn          121
# 2      Manhattan          106
# 3         Queens           80
# 4  Staten Island           10
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# count_schools_borough['school_name'].plot(kind='hist', bins=20, title='school_name')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# count_schools_borough.groupby('borough').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
# ...

# %%
import seaborn as sns
sns.barplot( x= "borough", y = "school_name", data = count_schools_borough)
# Out:
# <Axes: xlabel='borough', ylabel='school_name'>

# %%
avg_number_students = df.groupby(['borough'])['total_students'].mean()

# %%
avg_number_students
# Out:
# borough
# Bronx             490.406780
# Brooklyn          699.134454
# Manhattan         589.825243
# Queens           1046.644737
# Staten Island    1847.500000
# Name: total_students, dtype: float64

# %%
summary_of_maxspan = df.groupby(['borough'])['expgrade_span_max'].describe()
summary_of_maxspan
# Out:
#                count       mean       std   min   25%   50%   75%   max
# borough
# Bronx            9.0  12.222222  0.666667  12.0  12.0  12.0  12.0  14.0
# Brooklyn         5.0  12.400000  0.894427  12.0  12.0  12.0  12.0  14.0
# Manhattan        9.0  12.444444  0.881917  12.0  12.0  12.0  12.0  14.0
# Queens          10.0  12.400000  0.843274  12.0  12.0  12.0  12.0  14.0
# Staten Island    0.0        NaN       NaN   NaN   NaN   NaN   NaN   NaN

# %% [markdown]
# Observations:  1. Staten Islands has the lowest number of schools however the average number of students are higher.
